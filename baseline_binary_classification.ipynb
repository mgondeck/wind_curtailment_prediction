# %% [markdown]
# <a href="https://colab.research.google.com/github/mgondeck/wind_curtailment_prediction/blob/mary/baseline_binary_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Deep learning binary classification model

# %%
# packages
import os
import pandas as pd

# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive')

# Path to the token file in your Google Drive
token_file_path = '/content/drive/My Drive/ignore/github_token.txt'

# Read the token from the file
with open(token_file_path, 'r') as file:
    github_token = file.read().strip()

# clone repo
# !git clone https://mgondeck:{github_token}@github.com/mgondeck/wind_curtailment_prediction.git

# navigate in project folder
os.chdir("/content/wind_curtailment_prediction")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# fatal: destination path 'wind_curtailment_prediction' already exists and is not an empty directory.

# %%
# Searching for files
search_directory = '/content/drive/My Drive'

file_name = 'weather_data.csv'
def search_file(directory, filename):
    for root, dirs, files in os.walk(directory):
        if filename in files:
            return os.path.join(root, filename)
    return None

file_path = search_file(search_directory, file_name)
print("File found at:", file_path)
# Out:
# File found at: /content/drive/My Drive/Sasch & Maryam/weather_data.csv

# %%
df_weather = pd.read_csv('/content/drive/My Drive/ms_wind_curtailment_prediction/weather_data.csv', sep = ';', index_col=0)
df_redispatch_2023 = pd.read_csv('/content/drive/My Drive/ms_wind_curtailment_prediction/wind_redispatch_2023.csv', sep = ';', index_col=0)

# %%
df_weather.head()
# Out:
#                                        date  ws_value  wd_value  rg_value  \
# station_id
# 2907        2022-01-01T00:00:00.000000+0000       6.2     270.0       0.0
# 2907        2022-01-01T00:00:00.000000+0000       6.2     270.0       0.0
# 2907        2022-01-01T00:00:00.000000+0000       6.2     270.0       0.0
# 2907        2022-01-01T00:00:00.000000+0000       6.2     270.0       0.0
# 2907        2022-01-01T00:10:00.000000+0000       6.4     270.0       0.0
#
#             at_value  h_value  wgm_value  ew_value  wdgm_value
# station_id
# 2907            92.3     92.3        9.7     280.0       280.0
# 2907            92.3     92.3        9.7       9.7       280.0
# 2907            92.3     92.3        9.7       4.3       280.0
# 2907            92.3     92.3        9.7       6.4       280.0
# 2907            92.2     92.2        9.3     260.0       260.0
